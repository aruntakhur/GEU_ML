# %% [markdown]
# <a href="https://colab.research.google.com/github/aruntakhur/GEU_ML/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Equation of the line is ​y = mx + c
# 1. Slope of the line is 1 i.e m = 1.
# 2. Intercept is 0 i.e. c = 0.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(1,10,11)
print(x)
# Out:
# [ 1.   1.9  2.8  3.7  4.6  5.5  6.4  7.3  8.2  9.1 10. ]

# %%
m = 1
y = m*x
plt.scatter(x,y)
plt.show()

# %%
print(x)
print(y)
# Out:
# [ 1.   1.9  2.8  3.7  4.6  5.5  6.4  7.3  8.2  9.1 10. ]
# [ 1.   1.9  2.8  3.7  4.6  5.5  6.4  7.3  8.2  9.1 10. ]

# %% [markdown]
# # Plotting Error function
# It has only one paramter
# ![LR_ErrorF.png](data:image/png;base64,...)

# %%
w1 = np.linspace(-6,9,11)
error = 0
input = len(x)
for i in range(input):
  error = error + (w1*x[i]- y[i])**2

# %%
print(error)
# Out:
# [20670.65   12760.9625  6749.6     2636.5625   421.85     105.4625
#   1687.4     5167.6625 10546.25   17823.1625 26998.4   ]

# %%
plt.plot(w1,error)
plt.xlabel('W')
plt.ylabel('Error')
plt.title('W vs Error')
plt.scatter(w1,error,c='red')
plt.show()

# %% [markdown]
# From the above graph we can see that minimum value of Error is 0 when w is equivalent to 1

# %% [markdown]
# ## Finding out the value of the paramters

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
xTx = np.dot(x,x)
w_ML = xTx**-1 * np.dot(x,y)

# %%
print(w_ML)
# Out:
# 1.0
